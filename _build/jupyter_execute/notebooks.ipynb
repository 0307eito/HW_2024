# %% [markdown]
# # OpenStreetMap
# 作業內容：嘗試用 Overpass API ，在自己的 Juptyer Notebook 中，使用如 Folium 或是其他地圖套件載入你感興趣的商家或設施。
#
# ## 全台灣釣具行分佈

# %%
import requests
import json
import folium
import overpass

# %%
overpass_url = "http://overpass-api.de/api/interpreter"

# 您可以根據需求修改這裡的查詢條件
overpass_query = """
[out:json];
node
  ["shop"="fishing"]
  (21.8,119.5,25.4,122.0);
out;
"""

response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()

# %%
m = folium.Map(location=[23.7, 121.0], zoom_start=8)

# 遍歷 Overpass API 的回應資料，並將每個點標記在地圖上
for element in data['elements']:
    lat = element['lat']
    lon = element['lon']
    name = element.get('tags', {}).get('name', 'Fishing Port')
    
    folium.Marker(
        location=[lat, lon],
        popup=name,
        icon=folium.Icon(icon='info-sign')
    ).add_to(m)

# 顯示地圖
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec213846e9d282c688fef4393a8a748b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec213846e9d282c688fef4393a8a748b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec213846e9d282c688fef4393a8a748b = L.map(
#                 &quot;map_ec213846e9d282c688fef4393a8a748b&quot;,
#                 {
#                     center: [23.7, 121.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_855ee0aeb262991059f26ae8eb5b4c06 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_855ee0aeb262991059f26ae8eb5b4c06.addTo(map_ec213846e9d282c688fef4393a8a748b);
#
#
#             var marker_3d2ac7f3ebdc17f25a3829872639b37e = L.marker(
#                 [24.2616745, 120.8136783],
#                 {}
#             ).addTo(map_ec213846e9d282c688fef4393a8a748b);
#
#
#             var icon_5883d31236245e0303bd9256dec1b154 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3d2ac7f3ebdc17f25a3829872639b37e.setIcon(icon_5883d31236245e0303bd9256dec1b154);
#
#
#         var popup_736ed1f752bf88fe257d800fd2435f77 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cf87994d0b9cf2acb08db8a03df7db00 = $(`&lt;div id=&quot;html_cf87994d0b9cf2acb08db8a03df7db00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;大統釣具店&lt;/div&gt;`)[0];
#                 popup_736ed1f752bf88fe257d800fd2435f77.setContent(html_cf87994d0b9cf2acb08db8a03df7db00);
#
#
#
#         marker_3d2ac7f3ebdc17f25a3829872639b37e.bindPopup(popup_736ed1f752bf88fe257d800fd2435f77)
#         ;
#
#
#
#
#             var marker_0d8d951ceb7b4b37c96b30e0cf69c66f = L.marker(
#                 [22.6271435, 120.344182],
#                 {}
#             ).addTo(map_ec213846e9d282c688fef4393a8a748b);
#
#
#             var icon_2969d3c64488ff4b92b21a229ea31b8f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0d8d951ceb7b4b37c96b30e0cf69c66f.setIcon(icon_2969d3c64488ff4b92b21a229ea31b8f);
#
#
#         var popup_373e6ab9b571d1965a9dade00955a91c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e0225363707f7221606867b570af7c00 = $(`&lt;div id=&quot;html_e0225363707f7221606867b570af7c00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;魚拓釣具&lt;/div&gt;`)[0];
#                 popup_373e6ab9b571d1965a9dade00955a91c.setContent(html_e0225363707f7221606867b570af7c00);
#
#
#
#         marker_0d8d951ceb7b4b37c96b30e0cf69c66f.bindPopup(popup_373e6ab9b571d1965a9dade00955a91c)
#         ;
#
#
#
#
#             var marker_01a26225ac2341b03f548e89db925301 = L.marker(
#                 [25.0195827, 121.4662673],
#                 {}
#             ).addTo(map_ec213846e9d282c688fef4393a8a748b);
#
#
#             var icon_b2958300c0e7d2c26791d48c71f78616 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_01a26225ac2341b03f548e89db925301.setIcon(icon_b2958300c0e7d2c26791d48c71f78616);
#
#
#         var popup_fd137964b302bff641d89e7a5d18df5b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_923c0f80b42f003f12de6249bef21b6a = $(`&lt;div id=&quot;html_923c0f80b42f003f12de6249bef21b6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;永濱釣具行&lt;/div&gt;`)[0];
#                 popup_fd137964b302bff641d89e7a5d18df5b.setContent(html_923c0f80b42f003f12de6249bef21b6a);
#
#
#
#         marker_01a26225ac2341b03f548e89db925301.bindPopup(popup_fd137964b302bff641d89e7a5d18df5b)
#         ;
#
#
#
#
#             var marker_4dfb7b484bed4ea4435a96b7ab94d694 = L.marker(
#                 [22.8079078, 120.2429556],
#                 {}
#             ).addTo(map_ec213846e9d282c688fef4393a8a748b);
#
#
#             var icon_20c3cb4ddbf8a7a052177f344e0ab11b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &qu
