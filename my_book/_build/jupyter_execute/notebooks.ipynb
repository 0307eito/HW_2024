# %% [markdown]
# # OpenStreetMap
# 作業內容：嘗試用 Overpass API ，在自己的 Juptyer Notebook 中，使用如 Folium 或是其他地圖套件載入你感興趣的商家或設施。
#
# ## 全台灣釣具行分佈

# %%
import requests
import json
import folium
import overpass

# %%
overpass_url = "http://overpass-api.de/api/interpreter"

# 您可以根據需求修改這裡的查詢條件
overpass_query = """
[out:json];
node
  ["shop"="fishing"]
  (21.8,119.5,25.4,122.0);
out;
"""

response = requests.get(overpass_url, 
                        params={'data': overpass_query})
data = response.json()

# %%
m = folium.Map(location=[23.7, 121.0], zoom_start=8)

# 遍歷 Overpass API 的回應資料，並將每個點標記在地圖上
for element in data['elements']:
    lat = element['lat']
    lon = element['lon']
    name = element.get('tags', {}).get('name', 'Fishing Port')
    
    folium.Marker(
        location=[lat, lon],
        popup=name,
        icon=folium.Icon(icon='info-sign')
    ).add_to(m)

# 顯示地圖
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f2dce488b1bd2dc8032a06486b768e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f2dce488b1bd2dc8032a06486b768e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6f2dce488b1bd2dc8032a06486b768e7 = L.map(
#                 &quot;map_6f2dce488b1bd2dc8032a06486b768e7&quot;,
#                 {
#                     center: [23.7, 121.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b3cd7b9053bac06cc137d7665a479f4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0b3cd7b9053bac06cc137d7665a479f4.addTo(map_6f2dce488b1bd2dc8032a06486b768e7);
#
#
#             var marker_d9b8826828c5bfcc5c6d06e42a955571 = L.marker(
#                 [24.2616745, 120.8136783],
#                 {}
#             ).addTo(map_6f2dce488b1bd2dc8032a06486b768e7);
#
#
#             var icon_fb4d7849a883964abf2690270ff9d80a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d9b8826828c5bfcc5c6d06e42a955571.setIcon(icon_fb4d7849a883964abf2690270ff9d80a);
#
#
#         var popup_d0d42bad9fed60aa164cd20599eec5e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1bc998d1deba693cec406a8e2483e5ad = $(`&lt;div id=&quot;html_1bc998d1deba693cec406a8e2483e5ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;大統釣具店&lt;/div&gt;`)[0];
#                 popup_d0d42bad9fed60aa164cd20599eec5e7.setContent(html_1bc998d1deba693cec406a8e2483e5ad);
#
#
#
#         marker_d9b8826828c5bfcc5c6d06e42a955571.bindPopup(popup_d0d42bad9fed60aa164cd20599eec5e7)
#         ;
#
#
#
#
#             var marker_34f859c61cb8993f76ca4665a1587de6 = L.marker(
#                 [22.6271435, 120.344182],
#                 {}
#             ).addTo(map_6f2dce488b1bd2dc8032a06486b768e7);
#
#
#             var icon_aec76e2c05cc80edfa7ea986a4b7f97a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_34f859c61cb8993f76ca4665a1587de6.setIcon(icon_aec76e2c05cc80edfa7ea986a4b7f97a);
#
#
#         var popup_b000c997e972076f474e34f79538de7f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2188964acba900950be0b2025ea1fa65 = $(`&lt;div id=&quot;html_2188964acba900950be0b2025ea1fa65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;魚拓釣具&lt;/div&gt;`)[0];
#                 popup_b000c997e972076f474e34f79538de7f.setContent(html_2188964acba900950be0b2025ea1fa65);
#
#
#
#         marker_34f859c61cb8993f76ca4665a1587de6.bindPopup(popup_b000c997e972076f474e34f79538de7f)
#         ;
#
#
#
#
#             var marker_f3692fa83fb7082e5ca3a2ba73ec6e68 = L.marker(
#                 [25.0195827, 121.4662673],
#                 {}
#             ).addTo(map_6f2dce488b1bd2dc8032a06486b768e7);
#
#
#             var icon_84850a2cdc734d32bc98e7c3c20e4f84 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f3692fa83fb7082e5ca3a2ba73ec6e68.setIcon(icon_84850a2cdc734d32bc98e7c3c20e4f84);
#
#
#         var popup_0761188152824b20484a3fed5de901db = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_03c5cb49b645c7337e806b586d078a04 = $(`&lt;div id=&quot;html_03c5cb49b645c7337e806b586d078a04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;永濱釣具行&lt;/div&gt;`)[0];
#                 popup_0761188152824b20484a3fed5de901db.setContent(html_03c5cb49b645c7337e806b586d078a04);
#
#
#
#         marker_f3692fa83fb7082e5ca3a2ba73ec6e68.bindPopup(popup_0761188152824b20484a3fed5de901db)
#         ;
#
#
#
#
#             var marker_2ecbee946011bec207a72bb9cead2924 = L.marker(
#                 [22.8079078, 120.2429556],
#                 {}
#             ).addTo(map_6f2dce488b1bd2dc8032a06486b768e7);
#
#
#             var icon_6e37089f8a4f719633b785f45c5b7e68 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &qu
